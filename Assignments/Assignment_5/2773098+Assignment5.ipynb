# %% [markdown]
# # Integration and Visualization
# - YOUR NAME: My Vu
# - YOUR VUNetID: mvu204
#
# (If you do not provide your NAME and VUNetID we will not accept your submission.)

# %% [markdown]
# ## Task 1 (2 Points):  Integrating ontologies in Protégé
# Take the ontology you built for Module 4 (let’s call it ontology A), and find either a fellow student with a similar ontology or an ontology on the web on similar domain. That will be our ontology B.
#
# Create an empty ontology in Protégé (ontology C), and import both ontologies.
#
# Define at least 6 mappings as following:
#
# -    1 mapping between a class from A and a class from B using rdfs:subClassOf
# -    1 mapping between a class from A and a class from B using owl:equivalentClass
# -    1 mapping between a property from A and a property from B using rdfs:subPropertyOf
# -    1 mapping between a property from A and a property from B using either owl:equivalentProperty, owl:disjointProperty, owl:inverseOf, or owl:propertyChainAxiom
# -    1 mapping between an individual from A and an individual from B using owl:differentFrom
# -    1 mapping between an individual from A and an individual from B using owl:sameAs
#
# The combined ontology should be **consistent**.
#
# Save the ontology as Turtle, where the filename is ‘mapping.ttl’
#
# Add all three ontologies to the ZIP file of this assignment, leaving preserved the original file names of the ontologies (i.e. the ones with the vunetIDs).

# %%
print(open('mapping.ttl').read())
# Out:
# @prefix : <http://example.com/ontology-c#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @base <http://example.com/ontology-c> .
#
# <http://example.com/ontology-c> rdf:type owl:Ontology ;
#                                  owl:imports <http://purl.org/ontology/bibo/> ,
#                                              <http://www.example.com/books> .
#
# #################################################################
# #    Object Properties
# #################################################################
#
# ###  http://purl.org/dc/terms/publisher
# <http://purl.org/dc/terms/publisher> owl:inverseOf <http://www.example.com/books#hasPublished> .
#
#
# ###  http://www.example.com/books#hasAuthor
# <http://www.example.com/books#hasAuthor> rdfs:subPropertyOf <http://purl.org/dc/terms/contributor> .
#
#
# ###  http://www.example.com/books#hasPublished
#
# #################################################################
# #    Classes
# #################################################################
#
# ###  http://purl.org/ontology/bibo/Book
# <http://purl.org/ontology/bibo/Book> owl:equivalentClass <http://www.example.com/books#Book> .
#
#
# ###  http://www.example.com/books#Book
#
# ###  http://www.example.com/books#Publisher
# <http://www.example.com/books#Publisher> rdfs:subClassOf <http://xmlns.com/foaf/0.1/Organization> .
#
#
# #################################################################
# #    Individuals
# #################################################################
#
# ###  http://example.com/ontology-c#Before_the_coffee_gets_cold
# :Before_the_coffee_gets_cold rdf:type owl:NamedIndividual ,
#                                       <http://purl.org/ontology/bibo/Book> .
#
#
# ###  http://example.com/ontology-c#Circe
# :Circe rdf:type owl:NamedIndividual ,
#                 <http://purl.org/ontology/bibo/Book> ;
#        owl:sameAs <http://www.example.com/books#Circe> ;
#        <http://purl.org/dc/terms/contributor> :Madeline_Miller .
#
#
# ###  http://example.com/ontology-c#Madeline_Miller
# :Madeline_Miller rdf:type owl:NamedIndividual ,
#                           <http://xmlns.com/foaf/0.1/Person> .
#
#
# ###  http://www.example.com/books#Circe
#
# #################################################################
# #    General axioms
# #################################################################
#
# [ rdf:type owl:AllDifferent ;
#   owl:distinctMembers ( :Before_the_coffee_gets_cold
#                         <http://www.example.com/books#Circe>
#                       )
# ] .
#
#
# ###  Generated by the OWL API (version 4.5.9.2019-02-01T07:24:44Z) https://github.com/owlcs/owlapi

# %% [markdown]
# ## Task 2 (1 Point):  Explain your mapping
#
# Please explain in a few sentences in the text field below the mapping you made in the previous question:
#
# The ontology that I integrated into my own, is the Bibliographical Ontology (bibo).
#
# -    rdfs:subClassOf - bibo uses the class foaf:Organization for organizations related to bibliographic items. I mapped my class books:Publisher to be the sub class of foaf:Organization
# -    owl:equivalentClass - bibo also has a class bibo:Book this is the same as my class books:Book. I mapped books:Book to be the equivalent class of bibo:Book
# -    rdfs:subPropertyOf - bibo has the property dcterms:contributor. This is used to link a bibliographic item to one of its contributor. So I mapped my property books:hasAuthor to be the sub property of dcterms:contributor
# -    owl:inverseOf - bibo has the property dcterms:publisher. Which is used like x dcterms:publisher y, where x is the book and y is the publisher. My ontology contains book:hasPublished. Which is the inverse of dcterms:publisher (publisher books:hasPublished book)
# -    owl:differentFrom - I mapped one book from bibo and one book from my ontology to be different from each other (bibo:Before_the_coffee_gets_cold and books:Circe)
# -    owl:sameAs - I mapped one book from bibo and one book from my ontology to be the same (bibo:Circe and books:Circe)

# %% [markdown]
# ## Task 3 (2 points):  Integration with SPARQL
#
# Before starting this task, make sure to watch the demo given in Lecture 10.
#
# Follow these instructions to complete this task:
#
# 1.    Open your GraphDB workbench.
# 2.    Create a new repository called assignment-5, and import your ontology A into this repository (you must have at least provided the Ontology A in the previous question).
# 3.    Given your initial ontology A and the domain it covers, find on the Web a public SPARQL endpoint that provides similar or complementary information (e.g. DBpedia, Wikidata, LinkedGeoData).
# 4.    From the SPARQL interface in GraphDB, write a SELECT query that you can use to retrieve this complementary or similar information from the SPARQL endpoint.
# 5.    Now also from the SPARQL interface in GraphDB, write an INSERT query to define mappings between the retrieved data and your ontology A. These mappings can be between classes in your ontology and classes in the retrieved data (e.g. using rdfs:subClassOf), between instances (e.g. using owl:sameAs), or between instances and classes (e.g. using rdf:type).
# 6.    After creating the mappings in GraphDB, export your RDF data, and check in Protégé if your ontology is consistent.
# 7.    If your ontology is still consistent, paste here both the SELECT query (step 4) and the INSERT query (step 5) that created these mappings. Otherwise, go back to Step 4.
#
# SELECT:
# ```sparql
#
#
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX books: <http://www.example.com/books>
# PREFIX : <http://www.example.com/books#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX wdt:  <http://www.wikidata.org/prop/direct/>
# PREFIX wd: <http://www.wikidata.org/entity/>
#
# SELECT ?authorWiki ?authorName ?book ?title
#     WHERE {
#     	?author rdf:type :Author.
#     	?author :hasName ?authorName.
#         SERVICE <https://query.wikidata.org/sparql>
#         {
#         	?authorWiki rdfs:label ?authorName .
#         	?authorWiki wdt:P106 wd:Q36180.
#             ?book wdt:P50 ?authorWiki .
#         ?book wdt:P1476 ?title .
#         }
#     }
# ```
#
# INSERT:
# ```sparql
#
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX books: <http://www.example.com/books>
# PREFIX : <http://www.example.com/books#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX wdt:  <http://www.wikidata.org/prop/direct/>
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT {?author owl:sameAs ?authorWiki}
# WHERE {
#     	?author rdf:type :Author.
#     	?author :hasName ?authorName.
#         SERVICE <https://query.wikidata.org/sparql>
#         {
#         	?authorWiki rdfs:label ?authorName .
#         	?authorWiki wdt:P106 wd:Q36180.
#             ?book wdt:P50 ?authorWiki .
#         ?book wdt:P1476 ?title .
#         }
#     }
#     ```

# %%
# %pip install ipython-sparql-pandas
# run `sparql?` in a cell for documentation
# %load_ext ipython_sparql_pandas

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# Requirement already satisfied: ipython-sparql-pandas in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (1.4)
# Requirement already satisfied: SPARQLWrapper in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython-sparql-pandas) (1.8.5)
# Requirement already satisfied: ipython in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython-sparql-pandas) (8.5.0)
# Requirement already satisfied: pandas in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython-sparql-pandas) (1.5.0)
# Requirement already satisfied: colorama in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.4.5)
# Requirement already satisfied: backcall in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.1.6)
# Requirement already satisfied: decorator in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (2.13.0)
# Requirement already satisfied: pickleshare in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (3.0.31)
# Requirement already satisfied: stack-data in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.5.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from ipython->ipython-sparql-pandas) (5.4.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from pandas->ipython-sparql-pandas) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from pandas->ipython-sparql-pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from pandas->ipython-sparql-pandas) (2022.4)
# Requirement already satisfied: rdflib>=4.0 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from SPARQLWrapper->ipython-sparql-pandas) (6.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from jedi>=0.16->ipython->ipython-sparql-pandas) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->ipython-sparql-pandas) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from python-dateutil>=2.8.1->pandas->ipython-sparql-pandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from rdflib>=4.0->SPARQLWrapper->ipython-sparql-pandas) (65.3.0)
# Requirement already satisfied: pyparsing in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from rdflib>=4.0->SPARQLWrapper->ipython-sparql-pandas) (3.0.9)
# Requirement already satisfied: isodate in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from rdflib>=4.0->SPARQLWrapper->ipython-sparql-pandas) (0.6.1)
# Requirement already satisfied: asttokens in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from stack-data->ipython->ipython-sparql-pandas) (2.0.8)
# Requirement already satisfied: executing in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from stack-data->ipython->ipython-sparql-pandas) (1.0.0)
# Requirement already satisfied: pure-eval in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from stack-data->ipython->ipython-sparql-pandas) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# The ipython_sparql_pandas extension is already loaded. To reload it, use:
#   %reload_ext ipython_sparql_pandas

# %% [markdown]
# ## Task 4 (2 point). Pandas Plotting
# First, make sure that `vuDataset.ttl` is loaded in GraphDb as the `repo-vu` repository.
#
# - **Task 4a:** Make a horizontal bar chart from the `courseload` dataframe
# - **Task 4b:** Write a new SPARQL query for DBpedia and create an interesting chart from it

# %%
# %%sparql http://localhost:7200/repositories/repo-vu -s courseload
# PREFIX vu: <http://example.org/vu/>
#
# SELECT ?teacher (COUNT(*) as ?courses) {
#     ?teacher vu:teaches ?o .
# } GROUP BY ?teacher
# Out:
#                         teacher  courses
# 0  http://example.org/vu/stefan        5
# 1   http://example.org/vu/frank        3
# 2     http://example.org/vu/joe        1

# %%
# Pandas visualization: https://pandas.pydata.org/docs/user_guide/visualization.html
courseload.set_index('teacher', inplace=True)
courseload['courses'].plot.pie()
# Out:
# <AxesSubplot: ylabel='courses'>

# %%
### Task 4a (1 point): Make a horizontal bar chart from the `courseload` dataframe
courseload['courses'].plot.barh()
# Out:
# <AxesSubplot: ylabel='teacher'>

# %%
### Task 4b (1 point): Write a new SPARQL query for DBpedia 
###    and create an interesting chart from it

# %%
# %%sparql http://dbpedia.org/sparql/ -q -s videogames
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# SELECT ?releaseYear (COUNT(*) AS ?numberOfGamesReleased)
# WHERE {
#   ?s rdf:type dbo:VideoGame .
#   ?s dbo:releaseDate ?releaseDate .
# }
# GROUP BY (year(xsd:dateTime(?releaseDate)) as ?releaseYear)
# ORDER BY ?releaseYear

# %%
videogames
# Out:
#     releaseYear  numberOfGamesReleased
# 0          1924                      1
# 1          1926                      1
# 2          1931                      1
# 3          1948                      1
# 4          1950                      1
# ..          ...                    ...
# 56         2018                    743
# 57         2019                    675
# 58         2020                    626
# 59         2021                    455
# 60         2022                     93
#
# [61 rows x 2 columns]

# %%
videogames.plot.line(x='releaseYear', y='numberOfGamesReleased')
# Out:
# <AxesSubplot: xlabel='releaseYear'>

# %% [markdown]
# ## Task 5 (1 point). Pandas styling
# Below is some code that shows a colored table.
#
# **Task:** Add a column with the percentage of the area of the country that is water.
# The background color of this column depend on its value: it should greener if more the country is land, and bluer if more of the country is water.

# %%
# %%sparql http://dbpedia.org/sparql/ -q -s dbpedia_countries
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX dcb: <http://dbpedia.org/resource/Category:>
# PREFIX dbo: <http://dbpedia.org/ontology/>
#
# SELECT DISTINCT ?name ?area_100k_km2 ?giniCoefficient ?waterPercentage WHERE {
#     ?country
#         dct:subject dcb:Current_member_states_of_the_United_Nations ;
#         dbo:area ?area ; # area is stated in m^2
#         dbo:giniCoefficient ?giniCoefficient ;
#         dbo:percentageOfAreaWater ?waterPercentage;
#         rdfs:label ?name.
#
#     BIND (ROUND(?area/100000000000) AS ?area_100k_km2)
#     FILTER(LANG(?name) = 'en')
# }
# ORDER BY DESC(?area_100k_km2)
# LIMIT 50

# %%
# Styling: https://pandas.pydata.org/docs/user_guide/style.html
# Using CSS Hue-Saturation-Level colors: https://www.w3schools.com/colors/colors_hsl.asp
def gini_color(gini):
    return f'background: hsl({100 - gini}, 100%, 50%)' 

def apply_colors(styler):
    styler.applymap(gini_color, subset=(slice(None), "giniCoefficient"))
    styler.background_gradient(subset="waterPercentage", cmap="winter_r")
    return styler

dbpedia_countries.style.pipe(apply_colors)
# Out:
# <style type="text/css">
# #T_66414_row0_col2 {
#   background: hsl(62.5, 100%, 50%);
# }
# #T_66414_row0_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_66414_row1_col2 {
#   background: hsl(69.7, 100%, 50%);
# }
# #T_66414_row1_col3 {
#   background-color: #0018f3;
#   color: #f1f1f1;
# }
# #T_66414_row2_col2 {
#   background: hsl(51.5, 100%, 50%);
# }
# #T_66414_row2_col3 {
#   background-color: #00a4ad;
#   color: #f1f1f1;
# }
# #T_66414_row3_col2 {
#   background: hsl(53.3, 100%, 50%);
# }
# #T_66414_row3_col3 {
#   background-color: #00c89b;
#   color: #000000;
# }
# #T_66414_row4_col2 {
#   background: hsl(46.6, 100%, 50%);
# }
# #T_66414_row4_col3, #T_66414_row23_col3 {
#   background-color: #00f386;
#   color: #000000;
# }
# #T_66414_row5_col2 {
#   background: hsl(67.5, 100%, 50%);
# }
# #T_66414_row5_col3 {
#   background-color: #00dc91;
#   color: #000000;
# }
# #T_66414_row6_col2 {
#   background: hsl(64.3, 100%, 50%);
# }
# #T_66414_row6_col3 {
#   background-color: #0042de;
#   color: #f1f1f1;
# }
# #T_66414_row7_col2 {
#   background: hsl(57.1, 100%, 50%);
# }
# #T_66414_row7_col3 {
#   background-color: #00e18e;
#   color: #000000;
# }
# #T_66414_row8_col2 {
#   background: hsl(72.5, 100%, 50%);
# }
# #T_66414_row8_col3 {
#   background-color: #00de90;
#   color: #000000;
# }
# #T_66414_row9_col2 {
#   background: hsl(72.4, 100%, 50%);
# }
# #T_66414_row9_col3 {
#   background-color: #00ea8a;
#   color: #000000;
# }
# #T_66414_row10_col2 {
#   background: hsl(57.9, 100%, 50%);
# }
# #T_66414_row10_col3 {
#   background-color: #00bea0;
#   color: #f1f1f1;
# }
# #T_66414_row11_col2 {
#   background: hsl(54.1, 100%, 50%);
# }
# #T_66414_row11_col3, #T_66414_row13_col3, #T_66414_row20_col3 {
#   background-color: #00f286;
#   color: #000000;
# }
# #T_66414_row12_col2 {
#   background: hsl(58.2, 100%, 50%);
# }
# #T_66414_row12_col3, #T_66414_row18_col3 {
#   background-color: #00e08f;
#   color: #000000;
# }
# #T_66414_row13_col2 {
#   background: hsl(67.3, 100%, 50%);
# }
# #T_66414_row14_col2 {
#   background: hsl(58.0, 100%, 50%);
# }
# #T_66414_row14_col3 {
#   background-color: #00df90;
#   color: #000000;
# }
# #T_66414_row15_col2 {
#   background: hsl(66.0, 100%, 50%);
# }
# #T_66414_row15_col3, #T_66414_row24_col3, #T_66414_row38_col3 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_66414_row16_col2 {
#   background: hsl(56.7, 100%, 50%);
# }
# #T_66414_row16_col3 {
#   background-color: #00da92;
#   color: #000000;
# }
# #T_66414_row17_col2 {
#   background: hsl(58.5, 100%, 50%);
# }
# #T_66414_row17_col3 {
#   background-color: #00f784;
#   color: #000000;
# }
# #T_66414_row18_col2, #T_66414_row46_col2 {
#   background: hsl(67.0, 100%, 50%);
# }
# #T_66414_row19_col2 {
#   background: hsl(37.0, 100%, 50%);
# }
# #T_66414_row19_col3, #T_66414_row45_col3 {
#   background-color: #00f883;
#   color: #000000;
# }
# #T_66414_row20_col2 {
#   background: hsl(65.0, 100%, 50%);
# }
# #T_66414_row21_col2 {
#   background: hsl(58.4, 100%, 50%);
# }
# #T_66414_row21_col3, #T_66414_row49_col3 {
#   background-color: #00e68c;
#   color: #000000;
# }
# #T_66414_row22_col2 {
#   background: hsl(48.7, 100%, 50%);
# }
# #T_66414_row22_col3, #T_66414_row32_col3 {
#   background-color: #00d694;
#   color: #000000;
# }
# #T_66414_row23_col2 {
#   background: hsl(68.5, 100%, 50%);
# }
# #T_66414_row24_col2 {
#   background: hsl(67.4, 100%, 50%);
# }
# #T_66414_row25_col2 {
#   background: hsl(64.9, 100%, 50%);
# }
# #T_66414_row25_col3 {
#   background-color: #00e48d;
#   color: #000000;
# }
# #T_66414_row26_col2 {
#   background: hsl(55.2, 100%, 50%);
# }
# #T_66414_row26_col3 {
#   background-color: #00c09f;
#   color: #f1f1f1;
# }
# #T_66414_row27_col2, #T_66414_row33_col2 {
#   background: hsl(68.4, 100%, 50%);
# }
# #T_66414_row27_col3, #T_66414_row33_col3 {
#   background-color: #00c79c;
#   color: #000000;
# }
# #T_66414_row28_col2 {
#   background: hsl(59.5, 100%, 50%);
# }
# #T_66414_row28_col3 {
#   background-color: #0081be;
#   color: #f1f1f1;
# }
# #T_66414_row29_col2 {
#   background: hsl(54.3, 100%, 50%);
# }
# #T_66414_row29_col3 {
#   background-color: #00d495;
#   color: #000000;
# }
# #T_66414_row30_col2, #T_66414_row47_col2 {
#   background: hsl(58.1, 100%, 50%);
# }
# #T_66414_row30_col3, #T_66414_row47_col3 {
#   background-color: #00d893;
#   color: #000000;
# }
# #T_66414_row31_col2 {
#   background: hsl(42.9, 100%, 50%);
# }
# #T_66414_row31_col3 {
#   background-color: #00ec89;
#   color: #000000;
# }
# #T_66414_row32_col2 {
#   background: hsl(54.0, 100%, 50%);
# }
# #T_66414_row34_col2, #T_66414_row48_col2 {
#   background: hsl(59.7, 100%, 50%);
# }
# #T_66414_row34_col3, #T_66414_row48_col3 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_66414_row35_col2 {
#   background: hsl(69.3, 100%, 50%);
# }
# #T_66414_row35_col3 {
#   background-color: #00c39e;
#   color: #000000;
# }
# #T_66414_row36_col2 {
#   background: hsl(73.4, 100%, 50%);
# }
# #T_66414_row36_col3 {
#   background-color: #0076c4;
#   color: #f1f1f1;
# }
# #T_66414_row37_col2 {
#   background: hsl(46.7, 100%, 50%);
# }
# #T_66414_row37_col3 {
#   background-color: #00ca9a;
#   color: #000000;
# }
# #T_66414_row38_col2 {
#   background: hsl(43.7, 100%, 50%);
# }
# #T_66414_row39_col2 {
#   background: hsl(70.8, 100%, 50%);
# }
# #T_66414_row39_col3 {
#   background-color: #00ef88;
#   color: #000000;
# }
# #T_66414_row40_col2 {
#   background: hsl(57.4, 100%, 50%);
# }
# #T_66414_row40_col3, #T_66414_row46_col3 {
#   background-color: #00ee88;
#   color: #000000;
# }
# #T_66414_row41_col2, #T_66414_row43_col2 {
#   background: hsl(59.2, 100%, 50%);
# }
# #T_66414_row41_col3 {
#   background-color: #00d296;
#   color: #000000;
# }
# #T_66414_row42_col2 {
#   background: hsl(73.1, 100%, 50%);
# }
# #T_66414_row42_col3 {
#   background-color: #005bd2;
#   color: #f1f1f1;
# }
# #T_66414_row43_col3 {
#   background-color: #009fb0;
#   color: #f1f1f1;
# }
# #T_66414_row44_col2 {
#   background: hsl(53.4, 100%, 50%);
# }
# #T_66414_row44_col3 {
#   background-color: #00f485;
#   color: #000000;
# }
# #T_66414_row45_col2 {
#   background: hsl(65.1, 100%, 50%);
# }
# #T_66414_row49_col2 {
#   background: hsl(70.3, 100%, 50%);
# }
# </style>
# <table id="T_66414">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66414_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_66414_level0_col1" class="col_heading level0 col1" >area_100k_km2</th>
#       <th id="T_66414_level0_col2" class="col_heading level0 col2" >giniCoefficient</th>
#       <th id="T_66414_level0_col3" class="col_heading level0 col3" >waterPercentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66414_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66414_row0_col0" class="data row0 col0" >Russia</td>
#       <td id="T_66414_row0_col1" class="data row0 col1" >171.000000</td>
#       <td id="T_66414_row0_col2" class="data row0 col2" >37.500000</td>
#       <td id="T_66414_row0_col3" class="data row0 col3" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66414_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66414_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_66414_row1_col1" class="data row1 col1" >100.000000</td>
#       <td id="T_66414_row1_col2" class="data row1 col2" >30.300000</td>
#       <td id="T_66414_row1_col3" class="data row1 col3" >11.760000</td>
#     </tr>
#     <tr>
#       <th id="T_66414_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66414_row2_col0" class="data row2 col0" >United States</td>
#       <td id="T_66414_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_66414_row2_col2" class="data row2 col2" >48.500000</td>
#       <td id="T_66414_row2_col3" class="data row2 col3" >4.660000</td>
#     </tr>
#     <tr>
#       <th id="T_66414_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66414_row3_col0" class="data row3 col0" >China</td>
#       <td id="T_66414_row3_col1" class="data row3 col1" >96.000000</td>
#       <td id="T_66414_row3_col2" class="data row3 col2" >46.700000</td>
#       <td id="T_66414_row3_col3" class="data row3 col3" >2.800000</td>
#     </tr>
#     <tr>
#       <th id="T_66414_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66414_row4_col0" class="data row4 col0" >Brazil</td>
#       <td id="T_66414_row4_col1" class="data row4 col1" >85.000000</td>
#       <td id="T_66414_row4_col2" class="data row4 col2" >53.400000</td>

# %% [markdown]
# # Task 6 (2 points): Folium Map
#
# Below is some code that makes a map.
#
# **Task:** Make the markers bigger depending on the population of the capital (but keep it readable!)
#
# Tip: use the auto-complete functionality of http://query.wikidata.org

# %%
# %%sparql http://query.wikidata.org/sparql -q -s capitals
# SELECT ?capitalLabel ?coords ?population WHERE {
#     ?country
#         wdt:P463 wd:Q458 ; # member of: European Union
#         wdt:P36 ?capital . # capital: ?capital
#
#     ?capital
#         wdt:P625 ?coords ; # coordinate location: ?coords
#         wdt:P1082 ?population.
#
#
#     # Using Wikidata-only label service
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }

# %%
# %pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.0/95.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from folium) (1.23.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thaom\anaconda3\envs\knowledge\lib\site-packages (from requests->folium) (2022.9.24)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
# Extract latitude and longitude from coordinates in Well-Known Text (WKT) format
capitals_coords = capitals.join(capitals.coords.str.extract('Point\((?P<lon>\S+) (?P<lat>\S+)\)').astype(float))

middle = [capitals_coords['lat'].mean(), capitals_coords['lon'].mean()]
m = folium.Map(location=middle, zoom_start=4)
for _, row in capitals_coords.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius= int(row['population'])/100000,
        popup= row['capitalLabel'],
        color="#3186cc",
        fill=True,
        fill_color="#3186cc"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_921ec87fbf1bad121e81c38ed7ff5916 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_921ec87fbf1bad121e81c38ed7ff5916&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_921ec87fbf1bad121e81c38ed7ff5916 = L.map(
#                 &quot;map_921ec87fbf1bad121e81c38ed7ff5916&quot;,
#                 {
#                     center: [48.387085693172416, 14.374156911620691],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4bb4ceb45eb8e1f1f988a18598d9b81 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_921ec87fbf1bad121e81c38ed7ff5916);
#
#
#             var circle_marker_779b78878285a85706b2ff7d28f306a7 = L.circleMarker(
#                 [52.516666666, 13.383333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 36.64088, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_921ec87fbf1bad121e81c38ed7ff5916);
#
#
#         var popup_8ac7f824a491747c4c9ca217327cc150 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e75791b24060a5e761a07bca7aa3bbd = $(`&lt;div id=&quot;html_0e75791b24060a5e761a07bca7aa3bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#             popup_8ac7f824a491747c4c9ca217327cc150.setContent(html_0e75791b24060a5e761a07bca7aa3bbd);
#
#
#         circle_marker_779b78878285a85706b2ff7d28f306a7.bindPopup(popup_8ac7f824a491747c4c9ca217327cc150)
#         ;
#
#
#
#
#             var circle_marker_2164303f08569fb90066ba88ab63ef49 = L.circleMarker(
#                 [51.507222222, -0.1275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 89.08081, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_921ec87fbf1bad121e81c38ed7ff5916);
#
#
#         var popup_00fd20cc78fa317496c02a9893e944fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3aea36021a7fd28834d9e375cb400c4 = $(`&lt;div id=&quot;html_f3aea36021a7fd28834d9e375cb400c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#             popup_00fd20cc78fa317496c02a9893e944fb.setContent(html_f3aea36021a7fd28834d9e375cb400c4);
#
#
#         circle_marker_2164303f08569fb90066ba88ab63ef49.bindPopup(popup_00fd20cc78fa317496c02a9893e944fb)
#         ;
#
#
#
#
#             var circle_marker_406c53112ce62a828ef993b1c7e7d41a = L.circleMarker(
#                 [48.856944444, 2.351388888],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21.65423, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_921ec87fbf1bad121e81c38ed7ff5916);
#
#
#         var popup_76224c2809a605a2ba6216612ef86ebf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_81013c79d81367f9871a2552ece108ae = $(`&lt;div id=&quot;html_81013c79d81367f9871a2552ece108ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#             popup_76224c2809a605a2ba6216612ef86ebf.setContent(html_81013c79d81367f9871a2552ece108ae);
#
#
#         circle_marker_406c53112ce62a828ef993b1c7e7d41a.bindPopup(popup_76224c2809a605a2ba6216612ef86ebf)
#         ;
#
#
#
#
#             var circle_marker_add70fd7703ede28db68e9c3da2c0b3c = L.circleMarker(
#                 [54.687222222, 25.28],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&qu
